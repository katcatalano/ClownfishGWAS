# %%
library(data.table)
library(ggplot2)
library(dplyr)
library(viridis)
library(qqman)

"%!in%" <- function(x,table) match(x,table, nomatch = 0) == 0
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: viridisLite
#
# Attaching package: ‘viridis’
#
# The following object is masked from ‘package:viridisLite’:
#
#     viridis.map
#
#
# For example usage please run: vignette('qqman')
#
# Citation appreciated but not required:
# Turner, (2018). qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. Journal of Open Source Software, 3(25), 731, https://doi.org/10.21105/joss.00731.

# %%
#check out angsd results
hwe <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/appc_angsd.hwe.gz")
setnames(hwe, 9, "p")

# %%
head(hwe)
# Out:
#   Chromo     Position Major Minor hweFreq  Freq     F         LRT
# 1 CM009708.1  164     A     G     0.143948 0.143978 -0.012379 0.004032974
# 2 CM009708.1  479     T     A     0.098266 0.099586 -0.109246 0.309823700
# 3 CM009708.1  480     T     G     0.167168 0.176823 -0.214118 1.518999000
# 4 CM009708.1  787     C     T     0.411355 0.409284 -0.317570 0.795253300
# 5 CM009708.1 1492     T     G     0.122028 0.124322 -0.139868 0.466126500
# 6 CM009708.1 2973     C     T     0.096377 0.099344 -0.109185 0.381258200
#   p
# 1 0.9493638
# 2 0.5777884
# 3 0.2177710
# 4 0.3725164
# 5 0.4947746
# 6 0.5369306

# %%
plot(hwe$hweFreq, hwe$Freq) #no super obvious het problems
# Out:
# plot without title

# %%
#how do maf and calls across ind look
maf <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/appc_angsd.mafs.gz")
head(maf)
# Out:
#   chromo     position major minor knownEM  pK-EM        nInd
# 1 CM009708.1  164     A     G     0.144025 4.856635e-08 28
# 2 CM009708.1  479     T     A     0.098202 4.630796e-10 34
# 3 CM009708.1  480     T     G     0.167226 5.107026e-14 33
# 4 CM009708.1  787     C     T     0.411443 0.000000e+00 23
# 5 CM009708.1 1492     T     G     0.122078 1.257505e-11 38
# 6 CM009708.1 2973     C     T     0.096310 8.409185e-07 38

# %%
#how many snps on each chrom
maf[, .N, by="chromo"]
# Out:
#     chromo         N
# 1   CM009708.1     318174
# 2   CM009709.1     307594
# 3   CM009710.1     282218
# 4   CM009711.1     270002
# 5   CM009712.1     271504
# 6   CM009713.1     307815
# 7   CM009714.1     313795
# 8   CM009715.1     264037
# 9   CM009716.1     272549
# 10  CM009717.1     366524
# 11  CM009718.1     271309
# 12  CM009719.1     270485
# 13  CM009720.1     275762
# 14  CM009721.1     249558
# 15  CM009722.1     272078
# 16  CM009723.1     242203
# 17  CM009724.1     260087
# 18  CM009725.1     224811
# 19  CM009726.1     238448
# 20  CM009727.1     227408
# 21  CM009728.1     220448
# 22  CM009729.1     203623
# 23  CM009730.1     190714
# 24  CM009731.1     146917
# 25  PYAM01000025.1  21613
# 26  PYAM01000127.1      7
# 27  PYAM01000128.1      2
# 28  PYAM01000129.1      3
# 29  PYAM01000130.1      6
# 30  PYAM01000133.1      4
# ... ...            ...
# 197 PYAM01000087.1  78
# 198 PYAM01000088.1  12
# 199 PYAM01000089.1  22
# 200 PYAM01000091.1  37
# 201 PYAM01000092.1 115
# 202 PYAM01000093.1   8
# 203 PYAM01000031.1  21
# 204 PYAM01000094.1   1
# 205 PYAM01000096.1  42
# 206 PYAM01000097.1   1
# 207 PYAM01000098.1   1
# 208 PYAM01000099.1   5
# 209 PYAM01000100.1 190
# 210 PYAM01000101.1   2
# 211 PYAM01000102.1  67
# 212 PYAM01000103.1  24
# 213 PYAM01000032.1  26
# 214 PYAM01000105.1   9
# 215 PYAM01000107.1  50
# 216 PYAM01000109.1  55
# 217 PYAM01000110.1 124
# 218 PYAM01000112.1  79
# 219 PYAM01000033.1   5
# 220 PYAM01000115.1  10
# 221 PYAM01000116.1   1
# 222 PYAM01000117.1  25
# 223 PYAM01000118.1   2
# 224 PYAM01000120.1   1
# 225 PYAM01000122.1   2
# 226 PYAM01000123.1   6

# %%
hist(maf$nInd)
hist(maf$knownEM)
# Out:
# Plot with title “Histogram of maf$nInd”
# Plot with title “Histogram of maf$knownEM”

# %%
hist(maf[knownEM < 0.1, nInd]) #for the really low maf, what's the distribution of individuals the snp was found in? make sure the nInd GL filter worked as expected
# Out:
# Plot with title “Histogram of maf[knownEM < 0.1, nInd]”

# %%
6295181/5886701
# Out:
# [1] 1.06939

# %%
#plot the pcangsd results, color by phenotypes in the association

# %%
pca <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/output_appc_filter.pcangsd.cov")

# %%
dim(pca)
# Out:
# [1] 155 155

# %%
#get eigenvalues
ev <-eigen(pca)
ev_dt <- data.table(ev$vectors[,1:10])
setnames(ev_dt, c("pc1", "pc2", "pc3", "pc4", "pc5", "pc6", "pc7", "pc8", "pc9", "pc10"))

# %%
#variance explained?
ev$values/sum(ev$values)
# Out:
#   [1] 0.205610470 0.006190777 0.006167956 0.006140180 0.006130616 0.006122933
#   [7] 0.006114843 0.006109375 0.006091408 0.006068793 0.006052663 0.006047373
#  [13] 0.006043220 0.006038800 0.006034737 0.006020112 0.006010161 0.006002116
#  [19] 0.005996837 0.005989733 0.005978192 0.005968653 0.005959552 0.005956508
#  [25] 0.005948017 0.005945439 0.005940919 0.005938836 0.005932211 0.005927611
#  [31] 0.005926505 0.005917530 0.005901118 0.005897013 0.005895531 0.005893644
#  [37] 0.005887598 0.005877357 0.005870418 0.005850467 0.005837768 0.005829382
#  [43] 0.005825038 0.005816743 0.005808984 0.005803315 0.005795125 0.005786531
#  [49] 0.005769919 0.005767102 0.005754185 0.005743464 0.005714386 0.005702377
#  [55] 0.005696500 0.005683414 0.005677378 0.005576275 0.005531411 0.005458161
#  [61] 0.005429807 0.005243543 0.005223547 0.005200113 0.005182035 0.005165898
#  [67] 0.005157295 0.005133662 0.005108024 0.005098284 0.005092157 0.005084357
#  [73] 0.005074287 0.005066135 0.005060459 0.005052740 0.005040388 0.005033385
#  [79] 0.005028362 0.005001742 0.004992377 0.004981674 0.004966910 0.004950342
#  [85] 0.004927804 0.004908238 0.004887656 0.004879737 0.004852836 0.004848818
#  [91] 0.004836611 0.004833502 0.004830566 0.004826140 0.004819440 0.004797970
#  [97] 0.004786923 0.004781527 0.004775869 0.004770644 0.004753635 0.004751267
# [103] 0.004743909 0.004720957 0.004712277 0.004702726 0.004690470 0.004656679
# [109] 0.004654209 0.004650693 0.004643460 0.004639382 0.004628341 0.004607709
# [115] 0.004592801 0.004582723 0.004569853 0.004559748 0.004552188 0.004545885
# [121] 0.004531240 0.004516658 0.004505219 0.004494545 0.004492632 0.004483695
# [127] 0.004483054 0.004470518 0.004467598 0.004465986 0.004463255 0.004454020
# [133] 0.004449447 0.004445286 0.004444298 0.004442112 0.004436426 0.004432874
# [139] 0.004425787 0.004423385 0.004411238 0.004404917 0.004400261 0.004376097
# [145] 0.004369015 0.004361029 0.004323034 0.004302547 0.004285761 0.004222427
# [151] 0.004213470 0.004181885 0.004148055 0.004062119 0.003945714

# %%
#bamlist <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/bamlist.list.txt")
meta <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/Sample_Meta.txt")[is.na(Group), Group :=-999][Group=="High", Group:=1][Group=="Low", Group:=0][, .(sample=gen_id, ucrit=Ucrit, sl=SL, dam, sire, case=Group, capture=Capture)]

#case_control_pheno <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/case_control_pheno.ybin")
#setnames(case_control_pheno, "case")
#sl_pheno <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/SL_pheno.ybin")
#setnames(sl_pheno, "sl")
#ucrit_pheno <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/Ucrit_pheno.ybin")
#setnames(ucrit_pheno, "ucrit")

# %%
head(meta)
# Out:
#   sample         ucrit sl   dam  sire case capture
# 1 Pop01_APPC1611 8.13  4.40 D125 S144 1    Pop01
# 2 Pop01_APPC1917 1.20  4.35 D85  S173 0    Pop01
# 3 Pop01_APPC1921 7.33  4.28 D85  S173 1    Pop01
# 4 Pop01_APPC2029 8.82  4.25 D70  S98  1    Pop01
# 5 Pop01_APPC2030 7.32  4.54 D70  S98  1    Pop01
# 6 Pop01_APPC2101 5.07  3.94 D269 S94  1    Pop01

# %%
#meta[, bam_id := paste(Capture, larvalID, sep="_")] #make a name column consistent with bamlist
#join with bamlist
#bam_meta <- left_join(bamlist, meta, by=c(sample="gen_id"))[, .(sample, ucrit=Ucrit, sl=SL, dam, sire, case=Group, capture=Capture)]

# %%
#check that the angsd assoc phenotypes were in the right order
#(bam_meta$case==case_control_pheno$case)
#(bam_meta$ucrit== ucrit_pheno$ucrit)
#(bam_meta$sl== sl_pheno$sl)

# %%
pca_phenos <- cbind(meta , ev_dt)[, sequencing_lib := ifelse(capture %in% c("Pop01","Pop02","Pop03", "Pop04", "Pop05", "Pop06", "Pop07","Pop08"), 1, 2)]
# Out:
# Warning message in data.table::data.table(...):
# “Item 2 is of size 155 but maximum size is 159 (recycled leaving remainder of 4 items)”

# %%
head(pca_phenos)
# Out:
#   sample         ucrit sl   dam  sire case capture pc1          pc2
# 1 Pop01_APPC1611 8.13  4.40 D125 S144 1    Pop01   -0.092607712  0.0174850921
# 2 Pop01_APPC1917 1.20  4.35 D85  S173 0    Pop01   -0.114829109 -0.0122763883
# 3 Pop01_APPC1921 7.33  4.28 D85  S173 1    Pop01    0.003392844 -0.0002162177
# 4 Pop01_APPC2029 8.82  4.25 D70  S98  1    Pop01   -0.034442932 -0.9970604955
# 5 Pop01_APPC2030 7.32  4.54 D70  S98  1    Pop01    0.022761767 -0.0009952023
# 6 Pop01_APPC2101 5.07  3.94 D269 S94  1    Pop01    0.079684748  0.0003954962
#   pc3           pc4           pc5           pc6           pc7
# 1 -0.0244912829  0.0907109748 -0.1265772123  0.4548394971  0.2976397684
# 2 -0.0045606441  0.0091804647 -0.0074897431  0.0145264798  0.0036299967
# 3  0.0002983512 -0.0003594395  0.0003518672 -0.0006694834  0.0006781496
# 4  0.0148471171 -0.0148980018  0.0082823079 -0.0144668112  0.0025404022
# 5  0.0006811659 -0.0013575465  0.0010489719 -0.0019498312 -0.0004159890
# 6  0.0004661896 -0.0010765921  0.0009171700 -0.0014080925 -0.0027899947
#   pc8           pc9          pc10          sequencing_lib
# 1  0.7337473274 -0.328768016  0.0567937195 1
# 2 -0.0222023306  0.040585005 -0.0164666220 1
# 3  0.0007623382 -0.001938523  0.0007355999 1
# 4  0.0146947690 -0.023707844  0.0043610936 1
# 5  0.0031538522 -0.005274432  0.0012562488 1
# 6  0.0032181258 -0.003481662  0.0020461796 1

# %%
ForAngsdGWAS <- pca_phenos[, .(sample, phe1=ucrit, phe2=sl, phe3=case, cov1=pc1)]

# %%
#fwrite(ForAngsdGWAS, "~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/ForAngsdGWAS.sample", sep=",")

# %%
#fwrite(ForAngsdGWAS[, .(cov1)], "~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/pc1.cov")

# %%
(pca_phenos[pc4 >0.25])
(pca_phenos[pc4 < -0.05])
# Out:
#   sample         ucrit sl   dam sire case capture pc1         pc2
# 1 Pop02_APPC3226 0.47  4.14 D5  S137 0    Pop02   -0.08823504 0.02063531
#   pc3         pc4       pc5       pc6        pc7        pc8       pc9
# 1 -0.03159239 0.2533527 0.8714122 -0.2881431 0.09530932 0.1441154 -0.1692569
#   pc10       sequencing_lib
# 1 0.02646481 1
#   sample         ucrit sl   dam sire case capture pc1         pc2
# 1 Pop14_APPC0817 0.57  4.19 D13 S165 0    Pop14   -0.09680136 0.009726836
# 2 Pop14_APPC0821 7.48  4.42 D13 S165 1    Pop14   -0.09557951 0.009132825
# 3 Pop14_APPC0901 2.93  4.28 D26 S142 0    Pop14   -0.08702839 0.027944201
#   pc3          pc4        pc5        pc6          pc7        pc8
# 1 -0.009956151 -0.0981602 0.01398010 -0.009885956 -0.1705444 0.09634038
# 2 -0.010211836 -0.1019411 0.01457382 -0.010519950 -0.1839872 0.10188928
# 3 -0.048005713 -0.9314254 0.13642550 -0.149882830  0.1533879 0.06463432
#   pc9         pc10       sequencing_lib
# 1 -0.01444100 -0.5949654 2
# 2 -0.02185574 -0.6192059 2
# 3 -0.13624580  0.1463573 2

# %%
ggplot()+
    geom_point(data=pca_phenos, aes(x=pc1, y=pc5, col=as.factor(case)))
# Out:
# plot without title

# %%
p

# %%
ggplot()+
    geom_point(data=pca_phenos[], aes(x=pc1, y=pc2, col=sl)) +
    scale_color_viridis()
# Out:
# plot without title

# %%
ggplot()+
    geom_point(data=pca_phenos, aes(x=pc1, y=pc2, col=ucrit)) +
    scale_color_viridis()
# Out:
# plot without title

# %%
ggplot()+
    geom_point(data=pca_phenos, aes(x=pc1, y=pc2, col=sequencing_lib)) +
    scale_color_viridis()
# Out:
# plot without title

# %%
ggplot()+
    geom_point(data=pca_phenos, aes(x=pc1, y=pc2, col=capture))
# Out:
# plot without title

# %%
case_control_lrt <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/case_control_assoc_out.lrt0.gz")
#make a locus column 
case_control_lrt[, locus := paste(Chromosome, Position, sep=":")]

# %%
case_control_hwe <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/case_control_assoc_out.hwe.gz")
setnames(case_control_hwe, 9, "p")
#make a locus column 
case_control_hwe[, locus := paste(Chromo, Position, sep=":")]

# %%
summary(case_control_hwe[,9])

# %%
head(case_control_hwe)

# %%
#make sure loci not in hwe aren't in GWAS
nrow(case_control_lrt)
nrow(case_control_hwe)
#nope, there are because I set the threshold too low- should use 0.05- do that now
no_hwe_lrt <- case_control_lrt[locus %!in% case_control_hwe[p < 0.05, locus]]
nrow(case_control_lrt)-nrow(case_control_hwe[p < 0.05]) == nrow(no_hwe_lrt) #should be true

#filter other sites that have negative LRT
no_hwe_lrt_filt<-no_hwe_lrt[LRT >0]
nrow(no_hwe_lrt_filt) #number of sites included

# %%
head(no_hwe_lrt_filt)

# %%
#format for manhattan plot
#get pvalues
no_hwe_lrt_filt$pvalue<-dchisq(no_hwe_lrt_filt$LRT, df=1)
no_hwe_lrt_filt[, Chromosome := gsub(".","", Chromosome, fixed = T)][, Chromosome := gsub("CM","", Chromosome, fixed = T)][, Chromosome := gsub("PYAM","", Chromosome, fixed = T)]
no_hwe_lrt_filt[, Chromosome := as.numeric(Chromosome)]

# %%
no_hwe_lrt_filt$SNP<-paste("r",1:length(no_hwe_lrt_filt$Chromosome), sep="")

# %%
head(no_hwe_lrt_filt)

# %%
#What's the highest pvalue we get with the permuted phenotypes?
case_control_lrt_NULL <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/case_control_assoc_out_NULL.lrt0.gz")
case_control_lrt_NULL[, locus := paste(Chromosome, Position, sep=":")]
no_hwe_lrt_NULL <- case_control_lrt_NULL[locus %!in% case_control_hwe[p < 0.05, locus]]
nrow(no_hwe_lrt_NULL) == nrow(no_hwe_lrt) #should be true

#filter other sites that have negative LRT
no_hwe_lrt_filt_NULL<-no_hwe_lrt_NULL[LRT >0]
nrow(no_hwe_lrt_filt_NULL) #number of sites included
no_hwe_lrt_filt_NULL$pvalue<-dchisq(no_hwe_lrt_filt_NULL$LRT, df=1)
summary(no_hwe_lrt_filt_NULL$pvalue)

# %%
min(no_hwe_lrt_filt_NULL$pvalue)
min(no_hwe_lrt_filt$pvalue)

# %%
candidates <- no_hwe_lrt_filt[LRT > max(case_control_lrt_NULL$LRT)]

# %%
no_hwe_lrt_filt[pvalue < min(no_hwe_lrt_filt_NULL$pvalue)]

# %%
candidates

# %%
library(qqman)
man <- manhattan(no_hwe_lrt_filt, chr="Chromosome", bp="Position", p="pvalue", annotatePval =min(no_hwe_lrt_filt_NULL$pvalue))

# %%
qq_null <- qqnorm(no_hwe_lrt_filt_NULL$pvalue) #if the analysis structure is correct, then most points will be a line (because the null of "no association" is true for these) and there's a tail with a higher than expected sample p value

# %%
qq_null

# %%
qq <- qqnorm(no_hwe_lrt_filt$pvalue) #if the analysis structure is correct, then most points will be a line (because the null of "no association" is true for these) and there's a tail with a higher than expected sample p value

# %%
#are these SNPs also in the SL Gwas?
#What's the highest pvalue we get with the permuted phenotypes?
#sl_lrt <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/SL_quant_assoc_out.lrt0.gz")
#sl_lrt[, locus := paste(Chromosome, Position, sep=":")]
#no_hwe_lrt_sl <- sl_lrt[locus %!in% case_control_hwe[p < 0.05, locus]]
#nrow(no_hwe_lrt) == nrow(no_hwe_lrt) #should be true

#filter other sites that have negative LRT
no_hwe_lrt_filt_sl<-no_hwe_lrt_sl[LRTscore >0]
nrow(no_hwe_lrt_filt_sl) #number of sites included
no_hwe_lrt_filt_sl$pvalue<-dchisq(no_hwe_lrt_filt_sl$LRTscore, df=1)
summary(no_hwe_lrt_filt_sl$pvalue)

# %%
head(no_hwe_lrt_filt_sl[!is.na(beta)])

# %%
qqnorm(no_hwe_lrt_filt_sl$pvalue)

# %%
#lrt<-read.table(gzfile("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/case_control_assoc_out.lrt0.gz"), header=T, sep="\t")
#setDT(lrt)
#lrt <- lrt[LRT >0]

# %%
ordered <- case_control_lrt_filt[order(pvalue)]

# %%
(ordered[1:100])

# %%
summary(case_control_lrt_filt$pvalue)

# %%
#plot maf from angsd
maf<-fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/angsd/case_control_assoc_out.mafs.gz")
setDT(maf)

# %%
head(maf)

# %%
hist(maf$nInd)
summary(maf$nInd)

# %%
summary(maf$knownEM)
hist(maf$knownEM)

# %%
library(ape)
features <- fread("~/ClownfishGWAS/data/APPC_sequencing/DNA/trimmed_reads/mapping/genotypes/ncbi-genomes-2022-02-28//GCA_003047355.2_Nemo_v1.1_genomic.gbff.gff", skip = 6)

# %%
head(features)
